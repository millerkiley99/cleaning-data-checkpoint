# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset:https://www.kaggle.com/datasets/dsfelix/us-stores-sales
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd

sales_df = pd.read_csv("sales.csv")
sales_df.info()
sales_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248 entries, 0 to 4247
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Area Code       4248 non-null   int64
#  1   State           4248 non-null   object
#  2   Market          4248 non-null   object
#  3   Market Size     4248 non-null   object
#  4   Profit          4248 non-null   float64
#  5   Margin          4248 non-null   float64
#  6   Sales           4248 non-null   float64
#  7   COGS            4248 non-null   float64
#  8   Total Expenses  4248 non-null   float64
#  9   Marketing       4248 non-null   float64
#  10  Inventory       4248 non-null   float64
#  11  Budget Profit   4248 non-null   float64
#  12  Budget COGS     4248 non-null   float64
#  13  Budget Margin   4248 non-null   float64
#  14  Budget Sales    4248 non-null   float64
#  15  ProductId       4248 non-null   int64
#  16  Date            4248 non-null   object
# ...

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
sales_df.isnull().sum()
#no missing data
# Out:
# Area Code         0
# State             0
# Market            0
# Market Size       0
# Profit            0
# Margin            0
# Sales             0
# COGS              0
# Total Expenses    0
# Marketing         0
# Inventory         0
# Budget Profit     0
# Budget COGS       0
# Budget Margin     0
# Budget Sales      0
# ProductId         0
# Date              0
# Product Type      0
# Product           0
# Type              0
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
sales_df.describe()
# Out:
#          Area Code       Profit       Margin        Sales         COGS  \
# count  4248.000000  4248.000000  4248.000000  4248.000000  4248.000000
# mean    582.278013    61.097693   104.293315   192.987524    84.433145
# std     221.140310   101.708546    94.342522   151.133127    67.249769
# min     203.000000  -638.000000  -302.000000    17.000000     0.000000
# 25%     417.000000    17.000000    52.750000   100.000000    43.000000
# 50%     573.000000    40.000000    76.000000   138.000000    60.000000
# 75%     772.000000    92.000000   132.000000   230.000000   100.000000
# max     985.000000   778.000000   613.000000   912.000000   364.000000
#
#        Total Expenses    Marketing    Inventory  Budget Profit  Budget COGS  \
# count     4248.000000  4248.000000  4248.000000    4248.000000  4248.000000
# mean        54.063559    31.185028   749.381356      60.913371    74.830508
# std         32.352598    27.023264   661.031896      79.546123    66.238145
# ...

# %%
sales_df.boxplot(figsize=(15,8))
#Inventory Value of the Product in the Sale Moment has outliers but they may be needed projections so I will keep them.
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
#sales_df= sales_df.drop(columns= ['Area Code', 'Market', 'Date', 'Product Type', 'Product', 'Type'])
#Dropped columns that don't give me information for the Marketing vs Profit comparison.

# %%
sales_df.head()
# Out:
#          State   Market Size  Profit  Margin  Sales   COGS  Total Expenses  \
# 0  Connecticut  Small Market   107.0   176.0  292.0  116.0            69.0
# 1  Connecticut  Small Market    75.0   135.0  225.0   90.0            60.0
# 2  Connecticut  Small Market   122.0   195.0  325.0  130.0            73.0
# 3  Connecticut  Small Market   105.0   174.0  289.0  115.0            69.0
# 4  Connecticut  Small Market   104.0   135.0  223.0   90.0            56.0
#
#    Marketing  Inventory  Budget Profit  Budget COGS  Budget Margin  \
# 0       38.0      962.0          110.0        110.0          160.0
# 1       29.0     1148.0           90.0         80.0          130.0
# 2       42.0     1134.0          130.0        110.0          180.0
# 3       37.0     1166.0          110.0        100.0          160.0
# 4       29.0     1148.0           90.0         80.0          130.0
#
#    Budget Sales  ProductId
# 0         270.0          2
# 1         210.0          2
# ...

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
sales_df.tail()
#Comparing the costs vs profit for the top and bottom five products, the numbers seem to be consistent and relevant.
# Out:
#           State   Market Size  Profit  Margin  Sales  COGS  Total Expenses  \
# 4243  Louisiana  Small Market    -6.0    66.0  113.0  47.0            72.0
# 4244  Louisiana  Small Market    -7.0    61.0  105.0  44.0            68.0
# 4245  Louisiana  Small Market    -3.0    76.0  131.0  55.0            79.0
# 4246  Louisiana  Small Market     1.0    87.0  160.0  63.0            86.0
# 4247  Louisiana  Small Market     4.0    90.0  153.0  64.0            81.0
#
#       Marketing  Inventory  Budget Profit  Budget COGS  Budget Margin  \
# 4243       42.0     -395.0            0.0         40.0           50.0
# 4244       39.0     -508.0           10.0         30.0           60.0
# 4245       49.0    -1053.0            0.0         40.0           60.0
# 4246       57.0       37.0            0.0         50.0           70.0
# 4247       58.0     -113.0           10.0         50.0           80.0
#
#       Budget Sales  ProductId
# 4243          90.0          4
# 4244          90.0          4
# ...

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. Did you find all four types of dirty data in your dataset? No, I believe my data set may have been pre-cleaned or that they require all fields filled in per product.
# 2. Did the process of cleaning your data give you new insights into your dataset? Yes. I wanted to understand what costs they were using in the profit equation and that lead me to a better understanding of the different costs that go into the sales of a product.
# 3. Is there anything you would like to make note of when it comes to manipulating the data and making visualizations? I will dig more into Margin vs Profit for this comparison against the Marketing they put towards the sales.
